# %% [markdown]
# ## **<font color=red>python爬虫--京东评论爬取，写入DataFrame</font>**

# %%
import requests
import json
import time
import pymysql
import pandas as pd

# %%
#声明列表，以列表形式存储爬取到的数据
a = list()
b = list()
c = list()
d = list()
e = list()

for page in range(0,2):   #循环爬取前{?}页
    url = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=100011977044&score=0&sortType=5&page={}&pageSize=10&isShadowSku=0&fold=1'.format(page) 
    header = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36"}
    req = requests.get(url, headers=header)
    json_1 = req.text   #此处京东评论是放在json里的，其他情况是html较多
    py = json.loads(json_1.lstrip('fetchJSON_comment98(').rstrip(');'))   #解析json文件，将json文件转换为python字典，并将源码字典前面一大串不能解析的字符串去掉
    for i in py['comments']:   #py['comments']格式为列表list，里面是一个个字典dic，这里每一个i都是一个字典，i['id']取出的即是dic中key=‘id’对应的value，（列表中含有字典，用循环读取字典中的value）
        a.append(i['id'])   #将字段信息存储再list中       
        b.append(i['content'])
        c.append(i['creationTime'])
        d.append(i['score'])
        e.append(i['nickname'])
        
    time.sleep(1)   #设置1s的延时访问
    
dic = {"id":a,"nickname":e,"content":b,"time":c,"score":d}   #将list集合成dictionary从而用pd方法转化成Datarame
df = pd.DataFrame(dic)

df

# %%
#查看响应码
req.status_code
# Out:
# 200

# %% [markdown]
# *******

# %% [markdown]
#  **<font color=red size=5>京东评论爬取并用mysql存储</font>**

# %%
import pymysql

# %% [markdown]
# ID, NICKNAME, PRODUCTID, CONTENT, CREATIONTIME, SCORE, REPLYCOUNT, IMAGESTATUS, IMAGECOUNT, USEFULVOTECOUNT, VIDEOID

# %%
(ID CHAR(20) NOT NULL, NICKNAME CHAR(20), PRODUCTID CHAR(20), CONTENT VARCAHR(800), CREATIONTIME DATETIME NOT NULL, SCORE INT, REPLYCOUNT INT, IMAGESTATUS INT, IMAGECOUNT INT, USEFULVOTECOUNT INT)

# %% [markdown]
# **新建表格**

# %%
db = pymysql.connect(host = 'localhost',user = 'root',password = '123456',db = 'zeddhzm',charset='utf8')
cur = db.cursor()
sql = """CREATE TABLE JDCOMMENT_319(ID CHAR(20) NOT NULL, NICKNAME CHAR(20), CONTENT VARCHAR(800), CREATIONTIME DATETIME NOT NULL, SCORE INT, REPLYCOUNT INT, IMAGESTATUS CHAR(1), IMAGECOUNT CHAR(5), USEFULVOTECOUNT INT, WHETHERPLUS INT)"""
cur.execute(sql)
db.close()

# %% [markdown]
# **删除表格**

# %%
db = pymysql.connect(host = 'localhost',user = 'root',password = '123456',db = 'zeddhzm',charset='utf8')
cur = db.cursor()
sql = """DROP TABLE JDCOMMENT"""
cur.execute(sql)
db.close()

# %% [markdown]
# **爬取过程+导入mysql**

# %%
import requests
import json
import time
import pymysql
import winsound

# %%
URL11 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=1726938&score=1&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'
URL12 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=1726938&score=2&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'
URL13 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=1726938&score=3&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'

URL21 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=2783187&score=1&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'
URL22 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=2783187&score=2&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'
URL23 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=2783187&score=3&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'

URL31 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=31944131544&score=1&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'
URL32 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=31944131544&score=2&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'
URL33 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=31944131544&score=3&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'

URL41 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=2827520&score=1&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    
URL42 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=2827520&score=2&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    
URL43 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=2827520&score=3&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    

URL51 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=100000770620&score=1&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    
URL52 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=100000770620&score=2&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    
URL53 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=100000770620&score=3&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    

URL61 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=16049259636&score=1&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    
URL62 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=16049259636&score=2&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    
URL63 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=16049259636&score=3&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    

URL71 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=11268107649&score=1&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    
URL72 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=11268107649&score=2&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    
URL73 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=11268107649&score=3&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    

URL81 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=1844894&score=1&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    
URL82 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=1844894&score=2&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    
URL83 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=1844894&score=3&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    

URL91 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=5310401&score=1&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    
URL92 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=5310401&score=2&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    
URL93 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=5310401&score=3&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'    

URL101 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=100006096881&score=1&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'
URL102 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=100006096881&score=2&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'
URL103 = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=100006096881&score=3&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'

# URL（31，32）（61，62）（71，72）（81，82）差评、中评数少于100页

# %%
urllist1 = [URL11,URL12,URL13,URL21,URL22,URL23]
urllist2 = [URL31,URL32,URL33,URL41,URL42,URL43]
urllist3 = [URL51,URL52,URL53,URL61,URL62,URL63]
urllist4 = [URL71,URL72,URL73,URL81,URL82,URL83]
urllist5 = [URL91,URL92,URL93,URL101,URL102,URL103]

# %%
#连接mysql数据库，创建游标
db = pymysql.connect(host = 'localhost',user = 'root',password = '123456',db = 'zeddhzm',charset='utf8')   
cur = db.cursor()   

#循环爬取前{?}页评论数据，并循环存储进入mysql
for uurl in urllist5:
    for page in range(0,100):   
        url = uurl.format(page) 
        header = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36"}
        req = requests.get(url, headers=header)
        json_1 = req.text   #此处京东评论是放在json里的，其他情况是html较多
        #此处京东评论json文件编码方式为'GBK'
        json_1.encode('utf-8')   #更改json文件编码为与数据库内设置的相同的'UTF-8'
        py = json.loads(json_1.lstrip('fetchJSON_comment98(').rstrip(');'))   #解析json文件，将json文件转换为python字典，并将源码字典前面一大串不能解析的字符串去掉 
        a = 0
        for i in py['comments']:   #py['comments']格式为列表list，里面是一个个字典dic，这里每一个i都是一个字典，i['id']取出的即是dic中key=‘id’对应的value，（列表中含有字典，用循环读取字典中的value）
            try:
                try:
                    sql = """INSERT INTO JDCOMMENT_319(ID,NICKNAME,CONTENT,CREATIONTIME,SCORE,REPLYCOUNT,IMAGESTATUS,IMAGECOUNT,USEFULVOTECOUNT,WHETHERPLUS) VALUES('%s','%s','%s','%s',%s,%s,%s,%s,%s,%s)"""%(i['id'],i['nickname'],i['content'],i['creationTime'],i['score'],i['replyCount'],i['imageStatus'],i['imageCount'],i['usefulVoteCount'],i['plusAvailable'])
                    cur.execute(sql)
                    db.commit()   #使用pymysql对数据进行更新的时候要调用db.commit()
                except:
                    a += 1
                    sql = """INSERT INTO JDCOMMENT_319(ID,NICKNAME,CONTENT,CREATIONTIME,SCORE,REPLYCOUNT,IMAGESTATUS,IMAGECOUNT,USEFULVOTECOUNT,WHETHERPLUS) VALUES('%s','%s','%s','%s',%s,%s,%s,%s,%s,%s)"""%(i['id'],i['nickname'],i['content'],i['creationTime'],i['score'],i['replyCount'],'0','0',i['usefulVoteCount'],i['plusAvailable'])
                    cur.execute(sql)
                    db.commit()   #使用pymysql对数据进行更新的时候要调用db.commit()
                    continue
            except:
                continue
        print('URLLIST5中，%s的page%s有%s个comment无pic'%(uurl, page, a))
        time.sleep(4)   #设置延时访问
    
cur.close()
db.close()
winsound.Beep(500,3000)
print('urllist5结束')
# Out:
# URLLIST5中，https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=5310401&score=1&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1的page0有1个comment无pic
# URLLIST5中，https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=5310401&score=1&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1的page1有2个comment无pic
# URLLIST5中，https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=5310401&score=1&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1的page2有4个comment无pic
# URLLIST5中，https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=5310401&score=1&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1的page3有3个comment无pic
# URLLIST5中，https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=5310401&score=1&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1的page4有7个comment无pic
# ...

# %% [markdown]
# **<font color=blue size=4>文件编码方式：UTF-8，unicode，gbk，gb2312，ASCII 区别 https://blog.csdn.net/eightwhells/article/details/13350071
# 查看网页编码格式：F12-console-document.charset</font>**

# %%
#连接mysql数据库，创建游标
db = pymysql.connect(host = 'localhost',user = 'root',password = '123456',db = 'zeddhzm',charset='utf8')   
cur = db.cursor()   

#循环爬取前{?}页评论数据，并循环存储进入mysql
for page in range(0,100):   
    url = URL101.format(page) 
    header = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36"}
    req = requests.get(url, headers=header)
    json_1 = req.text   #此处京东评论是放在json里的，其他情况是html较多
    #此处京东评论json文件编码方式为'GBK'
    json_1.encode('utf-8')   #更改json文件编码为与数据库内设置的相同的'UTF-8'
    py = json.loads(json_1.lstrip('fetchJSON_comment98(').rstrip(');'))   #解析json文件，将json文件转换为python字典，并将源码字典前面一大串不能解析的字符串去掉 
    for i in py['comments']:   #py['comments']格式为列表list，里面是一个个字典dic，这里每一个i都是一个字典，i['id']取出的即是dic中key=‘id’对应的value，（列表中含有字典，用循环读取字典中的value）
        try:
            sql = """INSERT INTO JDCOMMENT3(ID,NICKNAME,CONTENT,CREATIONTIME,SCORE,REPLYCOUNT,IMAGESTATUS,IMAGECOUNT,USEFULVOTECOUNT) VALUES('%s','%s','%s','%s',%s,%s,%s,%s,%s)"""%(i['id'],i['nickname'],i['content'],i['creationTime'],i['score'],i['replyCount'],i['imageStatus'],i['imageCount'],i['usefulVoteCount'])
            cur.execute(sql)
            db.commit()   #使用pymysql对数据进行更新的时候要调用db.commit()
        except:
            sql = """INSERT INTO JDCOMMENT3(ID,NICKNAME,CONTENT,CREATIONTIME,SCORE,REPLYCOUNT,IMAGESTATUS,IMAGECOUNT,USEFULVOTECOUNT) VALUES('%s','%s','%s','%s',%s,%s,%s,%s,%s)"""%(i['id'],i['nickname'],i['content'],i['creationTime'],i['score'],i['replyCount'],'0','0',i['usefulVoteCount'])
            cur.execute(sql)
            db.commit()   #使用pymysql对数据进行更新的时候要调用db.commit()
            continue
    time.sleep(1)   #设置延时访问
    
cur.close()
db.close()
winsound.Beep(300,2000)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-9-458d7a354bd8> in <module>
#      11     #此处京东评论json文件编码方式为'GBK'
#      12     json_1.encode('utf-8')   #更改json文件编码为与数据库内设置的相同的'UTF-8'
# ---> 13     py = json.loads(json_1.lstrip('fetchJSON_comment98(').rstrip(');'))   #解析json文件，将json文件转换为python字典，并将源码字典前面一大串不能解析的字符串去掉
#      14     for i in py['comments']:   #py['comments']格式为列表list，里面是一个个字典dic，这里每一个i都是一个字典，i['id']取出的即是dic中key=‘id’对应的value，（列表中含有字典，用循环读取字典中的value）
#      15         try:
#
# D:\Softwares Installed\Anaconda\anaconda\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
# ...

# %%
import winsound 
print('winsound')
winsound.Beep(300,2000)
# Out:
# winsound
